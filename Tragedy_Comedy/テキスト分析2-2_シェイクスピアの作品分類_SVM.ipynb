# %%
###
###テキスト分析2_セル1
###

#シェイクスピアの作品分類
#テキストがGoogle Collaborator のファイルの保存位置に入る
import os
folder='texts'
if not os.path.isdir(folder):
  os.mkdir(folder)
# !wget -O $folder/shakespeares-works_TXT_FolgerShakespeare.zip https://flgr.sh/txtfssAlltxt?_ga=2.104281097.80727893.1702953543-617012875.1702953542
# !unzip -d $folder -o texts/shakespeares-works_TXT_FolgerShakespeare.zip
#終わりの何行を比較対象とするか
amount_of_last_lines=50
# Out:
# --2024-07-07 05:07:57--  https://flgr.sh/txtfssAlltxt?_ga=2.104281097.80727893.1702953543-617012875.1702953542
# Resolving flgr.sh (flgr.sh)... 3.138.82.213
# Connecting to flgr.sh (flgr.sh)|3.138.82.213|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://folger-main-site-assets.s3.amazonaws.com/uploads/2022/11/shakespeares-works_TXT_FolgerShakespeare.zip [following]
# --2024-07-07 05:07:57--  https://folger-main-site-assets.s3.amazonaws.com/uploads/2022/11/shakespeares-works_TXT_FolgerShakespeare.zip
# Resolving folger-main-site-assets.s3.amazonaws.com (folger-main-site-assets.s3.amazonaws.com)... 52.216.212.9, 3.5.28.169, 3.5.25.243, ...
# Connecting to folger-main-site-assets.s3.amazonaws.com (folger-main-site-assets.s3.amazonaws.com)|52.216.212.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2183684 (2.1M) [application/zip]
# Saving to: ‘texts/shakespeares-works_TXT_FolgerShakespeare.zip’
#
# texts/shakespeares- 100%[===================>]   2.08M  11.2MB/s    in 0.2s
#
# 2024-07-07 05:07:58 (11.2 MB/s) - ‘texts/shakespeares-works_TXT_FolgerShakespeare.zip’ saved [2183684/2183684]
#
# Archive:  texts/shakespeares-works_TXT_FolgerShakespeare.zip
#   inflating: texts/much-ado-about-nothing_TXT_FolgerShakespeare.txt
#   inflating: texts/richard-iii_TXT_FolgerShakespeare.txt
#   inflating: texts/the-winters-tale_TXT_FolgerShakespeare.txt
#   inflating: texts/richard-ii_TXT_FolgerShakespeare.txt
#   inflating: texts/henry-vi-part-3_TXT_FolgerShakespeare.txt
#   inflating: texts/the-two-noble-kinsmen_TXT_FolgerShakespeare.txt
#   inflating: texts/venus-and-adonis_TXT_FolgerShakespeare.txt
#   inflating: texts/timon-of-athens_TXT_FolgerShakespeare.txt
#   inflating: texts/the-merchant-of-venice_TXT_FolgerShakespeare.txt
#   inflating: texts/loves-labors-lost_TXT_FolgerShakespeare.txt
#   inflating: texts/troilus-and-cressida_TXT_FolgerShakespeare.txt
#    creating: texts/__MACOSX/
#   inflating: texts/__MACOSX/._troilus-and-cressida_TXT_FolgerShakespeare.txt
#   inflating: texts/a-midsummer-nights-dream_TXT_FolgerShakespeare.txt
#   inflating: texts/lucrece_TXT_FolgerShakespeare.txt
#   inflating: texts/henry-iv-part-1_TXT_FolgerShakespeare.txt
#   inflating: texts/henry-vi-part-1_TXT_FolgerShakespeare.txt
#   inflating: texts/henry-v_TXT_FolgerShakespeare.txt
#   inflating: texts/__MACOSX/._henry-v_TXT_FolgerShakespeare.txt
#   inflating: texts/pericles_TXT_FolgerShakespeare.txt
#   inflating: texts/the-merry-wives-of-windsor_TXT_FolgerShakespeare.txt
#   inflating: texts/as-you-like-it_TXT_FolgerShakespeare.txt
#   inflating: texts/king-john_TXT_FolgerShakespeare.txt
#   inflating: texts/cymbeline_TXT_FolgerShakespeare.txt
#   inflating: texts/alls-well-that-ends-well_TXT_FolgerShakespeare.txt
#   inflating: texts/henry-viii_TXT_FolgerShakespeare.txt
#   inflating: texts/julius-caesar_TXT_FolgerShakespeare.txt
#   inflating: texts/the-tempest_TXT_FolgerShakespeare.txt
#   inflating: texts/macbeth_TXT_FolgerShakespeare.txt
#   inflating: texts/hamlet_TXT_FolgerShakespeare.txt
#   inflating: texts/__MACOSX/._hamlet_TXT_FolgerShakespeare.txt
#   inflating: texts/the-taming-of-the-shrew_TXT_FolgerShakespeare.txt
#   inflating: texts/coriolanus_TXT_FolgerShakespeare.txt
#   inflating: texts/othello_TXT_FolgerShakespeare.txt
#   inflating: texts/shakespeares-sonnets_TXT_FolgerShakespeare.txt
#   inflating: texts/romeo-and-juliet_TXT_FolgerShakespeare.txt
#   inflating: texts/measure-for-measure_TXT_FolgerShakespeare.txt
#   inflating: texts/antony-and-cleopatra_TXT_FolgerShakespeare.txt
#   inflating: texts/__MACOSX/._antony-and-cleopatra_TXT_FolgerShakespeare.txt
#   inflating: texts/henry-vi-part-2_TXT_FolgerShakespeare.txt
#   inflating: texts/titus-andronicus_TXT_FolgerShakespeare.txt
#   inflating: texts/twelfth-night_TXT_FolgerShakespeare.txt
#   inflating: texts/henry-iv-part-2_TXT_FolgerShakespeare.txt
#   inflating: texts/king-lear_TXT_FolgerShakespeare.txt
#   inflating: texts/the-comedy-of-errors_TXT_FolgerShakespeare.txt
#   inflating: texts/the-phoenix-and-turtle_TXT_FolgerShakespeare.txt
#   inflating: texts/the-two-gentlemen-of-verona_TXT_FolgerShakespeare.txt

# %%
###
###テキスト分析2_セル2
###

#テクストを読み取り、前処理
import glob
import re
#前処理済みのテクストを格納する変数
titles=[]
plays=[]
#詩作品は除外
exclude_poems=['the-phoenix-and-turtle','venus-and-adonis','shakespeares-sonnets','lucrece']
#ディレクトリの中のテクストを一つずつ読み込む　例外：shakespeares-sonnets
for v in glob.glob(folder+'/*.txt'):
  #詩は除外
  title=v[len(folder)+1:v.find('_')]
  if title in exclude_poems:
    continue
  with open(v) as f:
    text=f.readlines()
  print(v)
#前処理1: 前書き（テクストの説明から登場人物までINDUCTION含む）とあとがきEPILOGUEを消す
  key=['ACT 1\n']
  text2=[]
  flag=0
  for i in text:
    if i in key:
      flag=1
    #ACT 1 より前までとEPILOGUEより後が消える
    if re.search(r'^EPILOGUE.*\n$', i)!=None:
      flag=0
    if flag!=0:
      text2.append(i)
  text3=[]
  togaki_flag=False
#前処理2: ACT1 Scene1(=, Chorus含む)といった文字を消す
  for i in text2:
    if re.search(r'^ACT [0-9].*\n$', i)!=None:
      i=''
    if re.search(r'^Scene [0-9].*\n$', i)!=None:
      i=''
    if re.search(r'^==.*\n$', i)!=None:
      i=''
    if re.search(r'^[0-9].*Chorus\n$', i)!=None:
      i=''
#前処理3: ト書き[]を消す
    #ト書き[]が1行内にある場合
    m=re.findall('\[[^\]]+\]',i)
    for j in m:
      i=i.replace(j,'')
    #ト書き[]が複数行にわたってある場合
    m=i.find('[')
    if m!=-1:
      i=re.sub('\[.*','',i)
      togaki_flag=True
    if togaki_flag:
      m=i.find(']')
      #その行全体がまだト書きの場合
      if m==-1:
        i=''
      #その行に終わりの]がある場合
      if m!=-1:
        i=i[m+1:]
        togaki_flag=False
#前処理4: 人物名を消す THESEUS  など。※ I に注意
    #人物の名前で始まる行
    m=re.search(r'^[A-Z]* *', i)
    if m!=None and len(m.group())>2:
      i=re.sub('^[A-Z]* *','', i)
    #人物の名前だけで改行している場合
    m=re.search(r'^[A-Z]*$', i)
    if m!=None and len(m.group())>1:
      i=re.sub('^[A-Z]*$','', i)
#前処理5: その他不要文字
    i=re.sub('\t','', i)
#前処理6: 改行を消す
    if i!='\n' and i!='':
      text3.append(i)
  titles.append(title)
  plays.append(text3)

#確認
print(titles)
print(plays[0])
# Out:
# texts/the-winters-tale_TXT_FolgerShakespeare.txt
# texts/the-tempest_TXT_FolgerShakespeare.txt
# texts/the-comedy-of-errors_TXT_FolgerShakespeare.txt
# texts/othello_TXT_FolgerShakespeare.txt
# texts/timon-of-athens_TXT_FolgerShakespeare.txt
# texts/richard-iii_TXT_FolgerShakespeare.txt
# texts/alls-well-that-ends-well_TXT_FolgerShakespeare.txt
# texts/king-lear_TXT_FolgerShakespeare.txt
# texts/antony-and-cleopatra_TXT_FolgerShakespeare.txt
# texts/the-merchant-of-venice_TXT_FolgerShakespeare.txt
# texts/richard-ii_TXT_FolgerShakespeare.txt
# texts/macbeth_TXT_FolgerShakespeare.txt
# texts/measure-for-measure_TXT_FolgerShakespeare.txt
# texts/henry-iv-part-2_TXT_FolgerShakespeare.txt
# texts/pericles_TXT_FolgerShakespeare.txt
# texts/as-you-like-it_TXT_FolgerShakespeare.txt
# texts/the-merry-wives-of-windsor_TXT_FolgerShakespeare.txt
# texts/hamlet_TXT_FolgerShakespeare.txt
# texts/julius-caesar_TXT_FolgerShakespeare.txt
# texts/the-two-gentlemen-of-verona_TXT_FolgerShakespeare.txt
# texts/cymbeline_TXT_FolgerShakespeare.txt
# texts/a-midsummer-nights-dream_TXT_FolgerShakespeare.txt
# texts/loves-labors-lost_TXT_FolgerShakespeare.txt
# texts/henry-v_TXT_FolgerShakespeare.txt
# texts/king-john_TXT_FolgerShakespeare.txt
# texts/twelfth-night_TXT_FolgerShakespeare.txt
# texts/the-taming-of-the-shrew_TXT_FolgerShakespeare.txt
# texts/henry-vi-part-3_TXT_FolgerShakespeare.txt
# texts/much-ado-about-nothing_TXT_FolgerShakespeare.txt
# texts/henry-viii_TXT_FolgerShakespeare.txt
# texts/henry-iv-part-1_TXT_FolgerShakespeare.txt
# texts/troilus-and-cressida_TXT_FolgerShakespeare.txt
# texts/romeo-and-juliet_TXT_FolgerShakespeare.txt
# texts/coriolanus_TXT_FolgerShakespeare.txt
# texts/henry-vi-part-2_TXT_FolgerShakespeare.txt
# texts/the-two-noble-kinsmen_TXT_FolgerShakespeare.txt
# texts/henry-vi-part-1_TXT_FolgerShakespeare.txt
# texts/titus-andronicus_TXT_FolgerShakespeare.txt
until You had drawn oaths from him not to stay. You, sir, Charge him too coldly. Tell him you are sure All in Bohemia's well. This satisfaction The bygone day proclaimed. Say this to him, He's beat from his best ward. Well said, Hermione. To tell he longs to see his son were strong. But let him say so then, and let him go. But let him swear so and he shall not stay; We'll thwack him hence with distaffs.  Yet of your royal presence I'll adventure The borrow of a week. When at Bohemia You take my lord, I'll give him my commission To let him there a month behind the gest Prefixed for 's parting.--Yet, good deed, Leontes, I love thee not a jar o' th' clock behind What lady she her lord.--You'll stay? No, madam. Nay, but you will? I may ...
# 38

# %%
###
###テキスト分析2_セル4
###

#機械学習用のラベルの作成。悲劇=1と喜劇=0に分ける。歴史劇は悲劇とする。
#hamletだけとっておく
labels_orig = {'alls-well-that-ends-well':	0,
	'a-midsummer-nights-dream':	0,
	'antony-and-cleopatra':	1,
	'as-you-like-it':	0,
	'coriolanus':	1,
	'cymbeline':	0,
	'hamlet':	1,
	'henry-iv-part-1':	1,
	'henry-iv-part-2':	1,
	'henry-v':	1,
	'henry-viii':	1,
	'henry-vi-part-1':	1,
	'henry-vi-part-2':	1,
	'henry-vi-part-3':	1,
	'julius-caesar':	1,
	'king-john':	1,
	'king-lear':	1,
	'loves-labors-lost':	0,
	'macbeth':	1,
	'measure-for-measure':	0,
	'much-ado-about-nothing':	0,
	'othello':	1,
	'pericles':	0,
	'richard-ii':	1,
	'richard-iii':	1,
	'romeo-and-juliet':	1,
	'the-comedy-of-errors':	0,
	'the-merchant-of-venice':	0,
	'the-merry-wives-of-windsor':	0,
	'the-taming-of-the-shrew':	0,
	'the-tempest':	0,
	'the-two-gentlemen-of-verona':	0,
	'the-two-noble-kinsmen':	0,
	'the-winters-tale':	0,
	'timon-of-athens':	1,
	'titus-andronicus':	1,
	'troilus-and-cressida':	0,
	'twelfth-night':	0}

'''
#悲劇、喜劇、歴史劇の３つに分けた場合
#labels_orig = {'alls-well-that-ends-well':	0,
	'a-midsummer-nights-dream':	0,
	'antony-and-cleopatra':	1,
	'as-you-like-it':	0,
	'coriolanus':	1,
	'cymbeline':	0,
	'hamlet':	1,
	'henry-iv-part-1':	2,
	'henry-iv-part-2':	2,
	'henry-v':	2,
	'henry-viii':	2,
	'henry-vi-part-1':	2,
	'henry-vi-part-2':	2,
	'henry-vi-part-3':	2,
	'julius-caesar':	1,
	'king-john':	2,
	'king-lear':	1,
	'loves-labors-lost':	0,
	'macbeth':	1,
	'measure-for-measure':	0,
	'much-ado-about-nothing':	0,
	'othello':	1,
	'pericles':	0,
	'richard-ii':	2,
	'richard-iii':	2,
	'romeo-and-juliet':	1,
	'the-comedy-of-errors':	0,
	'the-merchant-of-venice':	0,
	'the-merry-wives-of-windsor':	0,
	'the-taming-of-the-shrew':	0,
	'the-tempest':	0,
	'the-two-gentlemen-of-verona':	0,
	'the-two-noble-kinsmen':	0,
	'the-winters-tale':	0,
	'timon-of-athens':	1,
	'titus-andronicus':	1,
	'troilus-and-cressida':	0,
	'twelfth-night':	0}
'''

labels=[]
k=0
hamlet_num=0
hamlet_popped_flag=1
for i in titles:
  labels.append(labels_orig[i])
  if i == 'hamlet':
    hamlet_num=k
  k+=1

# %%
###
###テキスト分析2_セル5
###

print(labels)
print(titles)
print(hamlet_num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fe60d093c190> in <cell line: 1>()
# ----> 1 print(labels)
#       2 print(titles)
#       3 print(hamlet_num)
#
# NameError: name 'labels' is not defined

# %%
###
###テキスト分析2_セル6
###

#scikitlearn のVectorizerとSnowball stemmerをインストール
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from nltk.stem.snowball import SnowballStemmer
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfTransformer

#先にデータすべてに対してステミングをする
stemmer = SnowballStemmer("english")

def sentence_tokenizer_stemmer(text):
    return " ".join([stemmer.stem(word) for word in text.split()])

plays_short2 = [sentence_tokenizer_stemmer(text) for text in plays_short]

#TfidfVectorizerの実行
vectorizer = TfidfVectorizer(encoding='utf-8', strip_accents=None, lowercase=True, preprocessor=None, tokenizer=None,
                             analyzer='word', stop_words='english', ngram_range=(1, 1),
                             min_df=1, norm='l2', smooth_idf=True)
#TfidfVectorizerを使って各劇作品の文章ベクトル(tfidf)を得る
matrix = vectorizer.fit_transform(plays_short2)

# %%
###
###テキスト分析2_セル7
###

matrix.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9db453e4c47e> in <cell line: 1>()
# ----> 1 matrix.shape
#
# NameError: name 'matrix' is not defined

# %%
###
###テキスト分析2_セル8
###

#hamletだけのぞく
print(hamlet_num)
matrix_hamlet=matrix[hamlet_num].toarray()
matrix2=matrix.toarray()
matrix3=np.delete(matrix2, hamlet_num,0)
if hamlet_popped_flag==1:
  popped_hamlet = labels.pop(hamlet_num)
  hamlet_popped_flag=0
print(len(labels))
print(len(matrix3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-189207dc4f1b> in <cell line: 2>()
#       1 #hamletだけのぞく
# ----> 2 print(hamlet_num)
#       3 matrix_hamlet=matrix[hamlet_num].toarray()
#       4 matrix2=matrix.toarray()
#       5 matrix3=np.delete(matrix2, hamlet_num,0)
#
# NameError: name 'hamlet_num' is not defined

# %%
###
###テキスト分析2_セル9
###

#SVMを使う
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

#データを分ける
input_train, input_test, output_train, output_test = train_test_split(matrix3, labels, test_size=0.1, random_state=None)

# %%
###
###テキスト分析2_セル10
###

#SVMを学習
svm = SVC(kernel='linear', random_state=None)
svm.fit(input_train, output_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8865e202051d> in <cell line: 2>()
#       1 #SVMを学習
# ----> 2 svm = SVC(kernel='linear', random_state=None)
#       3 svm.fit(input_train, output_train)
#
# NameError: name 'SVC' is not defined

# %%
###
###テキスト分析2_セル11
###

#できたモデルの精度の確認

pred_test = svm.predict(input_test)
accuracy_test = accuracy_score(output_test, pred_test)
print('テストデータの精度：',accuracy_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-e9b9ff9fedb9> in <cell line: 3>()
#       1 #できたモデルの精度の確認
#       2
# ----> 3 pred_test = svm.predict(input_test)
#       4 accuracy_test = accuracy_score(output_test, pred_test)
#       5 print('テストデータの精度：',accuracy_test)
#
# NameError: name 'svm' is not defined

# %%
###
###テキスト分析2_セル12
###

#hamletの予測
predict = svm.predict(matrix_hamlet)
predict_map=['喜劇','悲劇']
print('Hamletは'+predict_map[predict[0]]+'に分類しました。')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-80eb8f6990ef> in <cell line: 2>()
#       1 #hamletの予測
# ----> 2 predict = svm.predict(matrix_hamlet)
#       3 predict_map=['喜劇','悲劇']
#       4 print('Hamletは'+predict_map[predict[0]]+'に分類しました。')
#
# NameError: name 'svm' is not defined
